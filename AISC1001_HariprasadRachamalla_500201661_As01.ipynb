# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../input/iris-dataset/Iris.csv')

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ### Histogram:

# %%
df['sepal_length'].hist()

# %%
df['sepal_width'].hist(bins=15)

# %%
df['petal_length'].hist(bins=5)

# %% [markdown]
# ### Scatter Plot:

# %%
df.plot.scatter(x='sepal_length', y='petal_width')

# %%
df.plot.scatter(x='petal_length', y='sepal_width')

# %% [markdown]
# ### Box Plot:

# %%
df.plot.box()
